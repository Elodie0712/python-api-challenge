# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID               City      Lat       Lng  Max Temp  Humidity  \
# 0        0  port-aux-francais -49.3500   70.2167     39.09        75
# 1        1          hithadhoo  -0.6000   73.0833     82.81        75
# 2        2            aasiaat  68.7098  -52.8699      1.58        93
# 3        3             kodiak  57.7900 -152.4072     18.91        93
# 4        4  wailua homesteads  22.0669 -159.3780     72.03        88
#
#    Cloudiness  Wind Speed Country        Date
# 0          68       28.63      TF  1702109577
# 1          82        8.88      MV  1702109577
# 2          51        4.97      GL  1702109578
# 3           0        4.61      US  1702109579
# 4         100        5.75      US  1702109580

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
map_plot_1 = city_data_df.hvplot.points("Lng", 
                                      "Lat", 
                                      geo = True,
                                      color = "City",
                                      alpha = 0.6,
                                      size = "Humidity",
                                      tiles = "OSM"
                                     )

# Display the map
map_plot_1
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
# My Criteria (Max Temp 80 but nothing less than 73, humidity,80)
narrowed_df = city_data_df[(city_data_df['Max Temp'] < 80) & 
                            (city_data_df['Max Temp'] > 73)&
                            (city_data_df['Humidity']<80)]
# Drop any rows with null values
narrowed_df=narrowed_df.dropna().reset_index()

# Display sample data
narrowed_df
# Out:
#     index  City_ID                City      Lat       Lng  Max Temp  Humidity  \
# 0      70       70               natal  -5.7950  -35.2094     77.65        78
# 1     100      100          taguatinga -12.3857  -46.5711     75.18        51
# 2     119      119       port mathurin -19.6833   63.4167     79.63        72
# 3     145      145            baragaon  25.4333   82.8167     76.98        65
# 4     148      148          kingscliff -28.2667  153.5667     78.94        65
# 5     154      154             biltine  14.5333   20.9167     76.82        10
# 6     175      175            haiphong  20.8561  106.6822     75.11        78
# 7     177      177               la'ie  21.6477 -157.9253     73.36        74
# 8     181      181            alaghsas  17.0187    8.0168     73.56        14
# 9     188      188       cockburn town  21.4612  -71.1419     78.84        77
# 10    190      190             qinzhou  21.9500  108.6167     76.77        70
# 11    199      199            ishigaki  24.3448  124.1572     77.13        78
# 12    202      202              mahina -17.5065 -149.4890     78.57        78
# 13    212      212              namibe -15.1961   12.1522     77.45        74
# 14    253      253             chizhou  30.6578  117.4831     73.99        34
# 15    254      254              gebeit  21.0667   36.3167     78.48        54
# 16    270      270              touros  -5.1989  -35.4608     79.07        75
# 17    284      284               gulma  12.6423    4.3555     75.58        14
# 18    311      311              sangod  24.9167   76.2833     77.90        39
# 19    315      315                fada   9.5667    8.3000     79.50        16
# 20    340      340              trairi  -3.2778  -39.2689     79.02        77
# 21    383      383             daoukro   7.0591   -3.9631     77.74        70
# 22    390      390       haiku-pauwela  20.9219 -156.3051     75.51        79
# 23    410      410              itoman  26.1247  127.6694     75.97        66
# 24    421      421           piacabucu -10.4056  -36.4344     77.07        79
# 25    430      430         as sulayyil  20.4607   45.5779     77.25        22
# 26    435      435               kitui  -1.3670   38.0106     76.01        63
# 27    436      436              dukhan  25.4297   50.7858     73.87        52
# 28    442      442              pangai -19.8000 -174.3500     79.48        78
# 29    468      468              hirara  24.8000  125.2833     77.27        73
# 30    470      470                kone -21.0595  164.8658     75.97        64
# 31    482      482             keelung  25.1283  121.7419     78.94        75
# 32    488      488              bonthe   7.5264  -12.5050     79.47        79
# 33    495      495             isangel -19.5500  169.2667     75.61        70
# 34    509      509            wenchang  30.9040  118.4887     73.20        34
# 35    527      527            saldanha -33.0117   17.9442     75.25        66
# 36    533      533           iranshahr  27.2025   60.6848     77.34        13
# 37    536      536               barah  13.7000   30.3667     77.41        13
# 38    537      537  san pedro pochutla  15.7333  -96.4667     73.89        76
# 39    543      543           road town  18.4167  -64.6167     78.89        71
#
#     Cloudiness  Wind Speed Country        Date
# 0           40        3.44      BR  1702109628
# 1           66        2.10      BR  1702109652
# 2           11        5.06      MU  1702109666
# 3            0        8.05      IN  1702109688
# 4            0       12.66      AU  1702109690
# 5          100        5.17      TD  1702109695
# 6           75        6.91      VN  1702109712
# 7           10        1.23      US  1702109714
# 8          100        5.14      NE  1702109717
# 9          100       23.26      TC  1702109724
# 10          56       13.04      CN  1702109726
# 11          20        8.05      JP  1702109732
# 12          75        2.30      PF  1702109735
# 13         100        5.50      AO  1702109743
# 14          85        3.65      CN  1702109774
# 15           0        5.88      SD  1702109775
# 16         100       15.19      BR  1702109787
# 17         100       12.50      NG  1702109798
# 18           0        5.39      IN  1702109816
# 19          29        4.63      NG  1702109819
# 20          76       12.59      BR  1702109638
# 21          35        0.85      CI  1702109767
# 22           0        5.75      US  1702109875
# 23          20       12.66      JP  1702109890
# 24          39       10.71      BR  1702109898
# 25          60       13.53      SA  1702109904
# 26          59        5.28      KE  1702109908
# 27          38        3.85      QA  1702109908
# 28         100       13.98      TO  1702109913
# 29          40        9.22      JP  1702109931
# 30         100        7.85      NC  1702109932
# 31          91        5.23      TW  1702109941
# 32           1        2.93      SL  1702109946
# 33         100       16.69      VU  1702109951
# 34         100        3.83      CN  1702109961
# 35           0       24.18      ZA  1702109974
# 36           0        0.00      IR  1702109978
# 37          87        9.08      SD  1702109980
# 38           7        3.06      MX  1702109981
# 39           1       24.29      VG  1702109985

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = narrowed_df.loc[:, ['City', 'Country', 'Lat', 'Lng',  'Humidity']]
hotel_df
#Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = ""
# Display sample data
hotel_df
# Out:
#                   City Country      Lat       Lng  Humidity Hotel Name
# 0                natal      BR  -5.7950  -35.2094        78
# 1           taguatinga      BR -12.3857  -46.5711        51
# 2        port mathurin      MU -19.6833   63.4167        72
# 3             baragaon      IN  25.4333   82.8167        65
# 4           kingscliff      AU -28.2667  153.5667        65
# 5              biltine      TD  14.5333   20.9167        10
# 6             haiphong      VN  20.8561  106.6822        78
# 7                la'ie      US  21.6477 -157.9253        74
# 8             alaghsas      NE  17.0187    8.0168        14
# 9        cockburn town      TC  21.4612  -71.1419        77
# 10             qinzhou      CN  21.9500  108.6167        70
# 11            ishigaki      JP  24.3448  124.1572        78
# 12              mahina      PF -17.5065 -149.4890        78
# 13              namibe      AO -15.1961   12.1522        74
# 14             chizhou      CN  30.6578  117.4831        34
# 15              gebeit      SD  21.0667   36.3167        54
# 16              touros      BR  -5.1989  -35.4608        75
# 17               gulma      NG  12.6423    4.3555        14
# 18              sangod      IN  24.9167   76.2833        39
# 19                fada      NG   9.5667    8.3000        16
# 20              trairi      BR  -3.2778  -39.2689        77
# 21             daoukro      CI   7.0591   -3.9631        70
# 22       haiku-pauwela      US  20.9219 -156.3051        79
# 23              itoman      JP  26.1247  127.6694        66
# 24           piacabucu      BR -10.4056  -36.4344        79
# 25         as sulayyil      SA  20.4607   45.5779        22
# 26               kitui      KE  -1.3670   38.0106        63
# 27              dukhan      QA  25.4297   50.7858        52
# 28              pangai      TO -19.8000 -174.3500        78
# 29              hirara      JP  24.8000  125.2833        73
# 30                kone      NC -21.0595  164.8658        64
# 31             keelung      TW  25.1283  121.7419        75
# 32              bonthe      SL   7.5264  -12.5050        79
# 33             isangel      VU -19.5500  169.2667        70
# 34            wenchang      CN  30.9040  118.4887        34
# 35            saldanha      ZA -33.0117   17.9442        66
# 36           iranshahr      IR  27.2025   60.6848        13
# 37               barah      SD  13.7000   30.3667        13
# 38  san pedro pochutla      MX  15.7333  -96.4667        76
# 39           road town      VG  18.4167  -64.6167        71

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
radius = 10000
params = {
    "categories": "accommodation.hotel", 
    "apiKey":  geoapify_key,
    "limit": 20 }

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    "categories": "accommodation.hotel", 
    "apiKey":  geoapify_key,
    }
        
# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    longitude = row["Lng"]
    latitude = row["Lat"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    # name_address = requests.get(base_url, params = params)
    
    # Convert the API response to JSON format
    name_address =requests.get(base_url, params = params).json() 
    # print(name_address)
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# natal - nearest hotel: Natal Palace Hotel
# taguatinga - nearest hotel: No hotel found
# port mathurin - nearest hotel: Escale Vacances
# baragaon - nearest hotel: No hotel found
# kingscliff - nearest hotel: Kingscliff Beach Hotel
# biltine - nearest hotel: فندق ثلاث نجوم بلتن
# haiphong - nearest hotel: Hoàng Hải Hotel
# la'ie - nearest hotel: No hotel found
# alaghsas - nearest hotel: Hôtel Zagado
# cockburn town - nearest hotel: The Salt Raker Inn
# qinzhou - nearest hotel: 天骄国际酒店
# ishigaki - nearest hotel: アートホテル石垣島
# mahina - nearest hotel: Motu Martin
# namibe - nearest hotel: Hotel Chik Chik Namibe
# chizhou - nearest hotel: 葡萄园大酒店
# gebeit - nearest hotel: No hotel found
# touros - nearest hotel: Pousada Atlântico
# gulma - nearest hotel: No hotel found
# sangod - nearest hotel: No hotel found
# fada - nearest hotel: No hotel found
# trairi - nearest hotel: Pousada Villa Aurora
# daoukro - nearest hotel: Hôtel BEKANTI
# haiku-pauwela - nearest hotel: Inn At Mama's Fish House
# itoman - nearest hotel: No hotel found
# piacabucu - nearest hotel: O Leão
# as sulayyil - nearest hotel: No hotel found
# kitui - nearest hotel: Parkside Hotel
# dukhan - nearest hotel: No hotel found
# pangai - nearest hotel: Billy's Place
# hirara - nearest hotel: 古謝そば屋
# kone - nearest hotel: Pacifik Appartels
# keelung - nearest hotel: 華國商務飯店
# bonthe - nearest hotel: No hotel found
# isangel - nearest hotel: Tanna Lodge
# wenchang - nearest hotel: No hotel found
# saldanha - nearest hotel: Hoedjesbaai
# iranshahr - nearest hotel: هتل قصِر
# barah - nearest hotel: No hotel found
# san pedro pochutla - nearest hotel: Olimpia
# road town - nearest hotel: No hotel found
#                   City Country      Lat       Lng  Humidity  \
# 0                natal      BR  -5.7950  -35.2094        78
# 1           taguatinga      BR -12.3857  -46.5711        51
# 2        port mathurin      MU -19.6833   63.4167        72
# 3             baragaon      IN  25.4333   82.8167        65
# 4           kingscliff      AU -28.2667  153.5667        65
# 5              biltine      TD  14.5333   20.9167        10
# 6             haiphong      VN  20.8561  106.6822        78
# 7                la'ie      US  21.6477 -157.9253        74
# 8             alaghsas      NE  17.0187    8.0168        14
# 9        cockburn town      TC  21.4612  -71.1419        77
# 10             qinzhou      CN  21.9500  108.6167        70
# 11            ishigaki      JP  24.3448  124.1572        78
# 12              mahina      PF -17.5065 -149.4890        78
# 13              namibe      AO -15.1961   12.1522        74
# 14             chizhou      CN  30.6578  117.4831        34
# 15              gebeit      SD  21.0667   36.3167        54
# 16              touros      BR  -5.1989  -35.4608        75
# 17               gulma      NG  12.6423    4.3555        14
# 18              sangod      IN  24.9167   76.2833        39
# 19                fada      NG   9.5667    8.3000        16
# 20              trairi      BR  -3.2778  -39.2689        77
# 21             daoukro      CI   7.0591   -3.9631        70
# 22       haiku-pauwela      US  20.9219 -156.3051        79
# 23              itoman      JP  26.1247  127.6694        66
# 24           piacabucu      BR -10.4056  -36.4344        79
# 25         as sulayyil      SA  20.4607   45.5779        22
# 26               kitui      KE  -1.3670   38.0106        63
# 27              dukhan      QA  25.4297   50.7858        52
# 28              pangai      TO -19.8000 -174.3500        78
# 29              hirara      JP  24.8000  125.2833        73
# 30                kone      NC -21.0595  164.8658        64
# 31             keelung      TW  25.1283  121.7419        75
# 32              bonthe      SL   7.5264  -12.5050        79
# 33             isangel      VU -19.5500  169.2667        70
# 34            wenchang      CN  30.9040  118.4887        34
# 35            saldanha      ZA -33.0117   17.9442        66
# 36           iranshahr      IR  27.2025   60.6848        13
# 37               barah      SD  13.7000   30.3667        13
# 38  san pedro pochutla      MX  15.7333  -96.4667        76
# 39           road town      VG  18.4167  -64.6167        71
#
#                   Hotel Name
# 0         Natal Palace Hotel
# 1             No hotel found
# 2            Escale Vacances
# 3             No hotel found
# 4     Kingscliff Beach Hotel
# 5        فندق ثلاث نجوم بلتن
# 6            Hoàng Hải Hotel
# 7             No hotel found
# 8               Hôtel Zagado
# 9         The Salt Raker Inn
# 10                    天骄国际酒店
# 11                 アートホテル石垣島
# 12               Motu Martin
# 13    Hotel Chik Chik Namibe
# 14                    葡萄园大酒店
# 15            No hotel found
# 16         Pousada Atlântico
# 17            No hotel found
# 18            No hotel found
# 19            No hotel found
# 20      Pousada Villa Aurora
# 21             Hôtel BEKANTI
# 22  Inn At Mama's Fish House
# 23            No hotel found
# 24                    O Leão
# 25            No hotel found
# 26            Parkside Hotel
# 27            No hotel found
# 28             Billy's Place
# 29                     古謝そば屋
# 30         Pacifik Appartels
# 31                    華國商務飯店
# 32            No hotel found
# 33               Tanna Lodge
# 34            No hotel found
# 35               Hoedjesbaai
# 36                  هتل قصِر
# 37            No hotel found
# 38                   Olimpia
# 39            No hotel found

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
hotel = hotel_df.hvplot.points("Lng", 
                                   "Lat", 
                                   geo = True,
                                   color = "City",
                                   alpha = 0.8,
                                   size = "Humidity",
                                   tiles = "OSM",
                                   hover_cols = ["Hotel Name", "Country"]
                                  )

# Display the map
hotel
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
